# %%
source('../src/load_data.r')
source('../src/multiplot.r')

# %%
dim(housing_df)
# Out:
# [1] 1451   80

# %%
head(housing_df)
# Out:
#   MSSubClass MSZoning LotFrontage LotArea LotShape LandContour Utilities
# 1 60         RL       65           8450   Reg      Lvl         AllPub
# 2 20         RL       80           9600   Reg      Lvl         AllPub
# 3 60         RL       68          11250   IR1      Lvl         AllPub
# 4 70         RL       60           9550   IR1      Lvl         AllPub
# 5 60         RL       84          14260   IR1      Lvl         AllPub
# 6 50         RL       85          14115   IR1      Lvl         AllPub
#   LotConfig LandSlope Neighborhood ⋯ PoolArea PoolQC  Fence   MiscFeature
# 1 Inside    Gtl       CollgCr      ⋯ 0        without without without
# 2 FR2       Gtl       Veenker      ⋯ 0        without without without
# 3 Inside    Gtl       CollgCr      ⋯ 0        without without without
# 4 Corner    Gtl       Crawfor      ⋯ 0        without without without
# 5 FR2       Gtl       NoRidge      ⋯ 0        without without without
# 6 Inside    Gtl       Mitchel      ⋯ 0        without MnPrv   Shed
#   MiscVal MoSold YrSold SaleType SaleCondition SalePrice
# 1   0     2      2008   WD       Normal        208500
# 2   0     5      2007   WD       Normal        181500
# 3   0     9      2008   WD       Normal        223500
# 4   0     2      2006   WD       Abnorml       140000
# 5   0     12     2008   WD       Normal        250000
# 6 700     10     2009   WD       Normal        143000

# %%
count_empty_total()

# %%
numeric_features = colnames(Filter(is.numeric, housing_df))
numeric_features
# Out:
#  [1] "LotFrontage"   "LotArea"       "YearBuilt"     "YearRemodAdd"
#  [5] "MasVnrArea"    "BsmtFinSF1"    "BsmtFinSF2"    "BsmtUnfSF"
#  [9] "TotalBsmtSF"   "FirstFlrSF"    "SecondFlrSF"   "LowQualFinSF"
# [13] "GrLivArea"     "GarageYrBlt"   "GarageArea"    "WoodDeckSF"
# [17] "OpenPorchSF"   "EnclosedPorch" "ThreeSsnPorch" "ScreenPorch"
# [21] "PoolArea"      "MiscVal"       "YrSold"        "SalePrice"

# %%
numeric_df = Filter(is.numeric, housing_df)
numeric_df$SalePrice <- NULL
numeric_features = colnames(numeric_df)

# %%
attach(numeric_df)

# %%
numeric_log_df = log(numeric_df+0.000001)
numeric_log_sc_df = data.frame(scale(numeric_log_df))

# %%
head(numeric_log_sc_df)
# Out:
#   LotFrontage LotArea    YearBuilt  YearRemodAdd MasVnrArea BsmtFinSF1
# 1 -0.08309725 -0.1316206  1.0509849  0.8820760    1.2091088 0.7205018
# 2  0.56397645  0.1149991  0.1692304 -0.4188065   -0.8272233 0.7552734
# 3  0.05751312  0.4215520  0.9860786  0.8342087    1.1887900 0.6806608
# 4 -0.33253709  0.1049061 -1.8680714 -0.7103048   -0.8272233 0.5941378
# 5  0.71602292  0.8798018  0.9536011  0.7384023    1.2709463 0.7125017
# 6  0.75290305  0.8600478  0.7258029  0.4984665   -0.8272233 0.7243605
# WoodDeckSF    -0.164114382  -0.0186265624 -0.090497725  0.035139786
# OpenPorchSF   -0.191927543   0.0202130426 -0.001945259  0.025204817
# EnclosedPorch  1.000000000  -0.0380034084 -0.078555533  0.002042675
# ThreeSsnPorch -0.038003408   1.0000000000 -0.038200672 -0.009025086
# ScreenPorch   -0.078555533  -0.0382006718  1.000000000  0.017753869
# PoolArea       0.002042675  -0.0090250864  0.017753869  1.000000000
# MiscVal        0.038466906   0.0049182894  0.015146223  0.042537910
# YrSold         0.004666952   0.0069909927  0.023353574 -0.057817089
#               MiscVal      YrSold
# LotFrontage    0.030678229  0.005022926
# LotArea        0.080109471 -0.025959684
# YearBuilt     -0.076256981 -0.014408357
# YearRemodAdd  -0.077398731  0.035228397
# MasVnrArea    -0.048885558 -0.002684037
# BsmtFinSF1     0.014995778  0.037229477
# BsmtFinSF2     0.032936186  0.026941188
# BsmtUnfSF     -0.017705405 -0.002505174
# TotalBsmtSF   -0.046624220 -0.029687553
# FirstFlrSF    -0.041785170 -0.015437305
# SecondFlrSF   -0.002345433 -0.015830952
# LowQualFinSF   0.028440899 -0.035035644
# GrLivArea     -0.038729769 -0.030402659
# GarageYrBlt   -0.048502718 -0.001415236
# GarageArea    -0.004524541 -0.012833686
# WoodDeckSF     0.007067187  0.019873876
# OpenPorchSF   -0.040539221 -0.067210930
# EnclosedPorch  0.038466906  0.004666952
# ThreeSsnPorch  0.004918289  0.006990993
# ScreenPorch    0.015146223  0.023353574
# PoolArea       0.042537910 -0.057817089
# MiscVal        1.000000000  0.059230093
# YrSold         0.059230093  1.000000000

# %%
library(reshape2)
cormat_log_sc = cor(numeric_log_sc_df)

cormat_log_sc[lower.tri(cormat_log_sc)] <- NA
diag(cormat_log_sc) <- NA

melted_cormat_log_sc <- melt(cormat_log_sc, na.rm = T)

library(ggplot2)
p1 <- ggplot(data = melted_cormat_log_sc, aes(Var2, Var1, fill = value))+
 geom_tile(color = "white")+
 scale_fill_gradient2(low = "blue", high = "red", mid = "white", 
   midpoint = 0, limit = c(-1,1), space = "Lab", 
   name="Pearson\nCorrelation") +
  theme_minimal()+ 
 theme(axis.text.x = element_text(angle = 45, vjust = 1, 
    size = 12, hjust = 1))+
 coord_fixed()

cormat = cor(numeric_df)

cormat[lower.tri(cormat)] <- NA
diag(cormat) <- NA

melted_cormat <- melt(cormat, na.rm = T)

library(ggplot2)
p2 <- ggplot(data = melted_cormat, aes(Var2, Var1, fill = value))+
 geom_tile(color = "white")+
 scale_fill_gradient2(low = "blue", high = "red", mid = "white", 
   midpoint = 0, limit = c(-1,1), space = "Lab", 
   name="Pearson\nCorrelation") +
  theme_minimal()+ 
 theme(axis.text.x = element_text(angle = 45, vjust = 1, 
    size = 12, hjust = 1))+
 coord_fixed()

p1; p2
# Out:
# plot without title
# plot without title
