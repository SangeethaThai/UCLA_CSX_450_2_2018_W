# %%
source('../src/load_data-01.r')

# %%
dim(housing_df)
# Out:
# [1] 1460   81

# %%
head(housing_df)
# Out:
#   X MSSubClass MSZoning LotFrontage LotArea LotShape LandContour Utilities
# 1 1 60         RL       65           8450   Reg      Lvl         AllPub
# 2 2 20         RL       80           9600   Reg      Lvl         AllPub
# 3 3 60         RL       68          11250   IR1      Lvl         AllPub
# 4 4 70         RL       60           9550   IR1      Lvl         AllPub
# 5 5 60         RL       84          14260   IR1      Lvl         AllPub
# 6 6 50         RL       85          14115   IR1      Lvl         AllPub
#   LotConfig LandSlope ⋯ PoolArea PoolQC Fence MiscFeature MiscVal MoSold YrSold
# 1 Inside    Gtl       ⋯ 0                                   0     2      2008
# 2 FR2       Gtl       ⋯ 0                                   0     5      2007
# 3 Inside    Gtl       ⋯ 0                                   0     9      2008
# 4 Corner    Gtl       ⋯ 0                                   0     2      2006
# 5 FR2       Gtl       ⋯ 0                                   0     12     2008
# 6 Inside    Gtl       ⋯ 0               MnPrv Shed        700     10     2009
#   SaleType SaleCondition SalePrice
# 1 WD       Normal        208500
# 2 WD       Normal        181500
# 3 WD       Normal        223500
# 4 WD       Abnorml       140000
# 5 WD       Normal        250000
# 6 WD       Normal        143000

# %%
nan_sums = colSums(is.na(housing_df))
nan_sums[nan_sums > 0]
# Out:
# LotFrontage  MasVnrArea GarageYrBlt
#         259           8          81

# %%
mean_LotFrontage <- mean(housing_df$LotFrontage, na.rm=T)
mean_MasVnrArea <- mean(housing_df$MasVnrArea, na.rm=T)
mean_GarageYrBlt <- mean(housing_df$GarageYrBlt, na.rm=T)

# %%
housing_df$LotFrontage[is.na(housing_df$LotFrontage)] <- mean_LotFrontage
housing_df$MasVnrArea[is.na(housing_df$MasVnrArea)] <- mean_MasVnrArea
housing_df$GarageYrBlt[is.na(housing_df$GarageYrBlt)] <- mean_GarageYrBlt

# %%
nan_sums = colSums(is.na(housing_df))
nan_sums[nan_sums > 0]
# Out:
# named numeric(0)

# %%
count_empty_values <- function (feature) {
    empty_string_mask = housing_df[feature] == ""
    return(length(housing_df[feature][empty_string_mask]))
}

count_empty_total <- function (){
    for (feature in colnames(housing_df)) {
        empty_count <- count_empty_values(feature)
        if (empty_count > 0) {
            print(paste(feature, empty_count))        
        }
    }
}

# %%
count_empty_total()
# Out:
# [1] "Alley 1369"
# [1] "MasVnrType 8"
# [1] "BsmtQual 37"
# [1] "BsmtCond 37"
# [1] "BsmtExposure 38"
# [1] "BsmtFinType1 37"
# [1] "BsmtFinType2 38"
# [1] "Electrical 1"
# [1] "FireplaceQu 690"
# [1] "GarageType 81"
# [1] "GarageFinish 81"
# [1] "GarageQual 81"
# [1] "GarageCond 81"
# [1] "PoolQC 1453"
# [1] "Fence 1179"
# [1] "MiscFeature 1406"

# %%
empty_means_without <-c("Alley","BsmtQual","BsmtCond","BsmtExposure","BsmtFinType1",
                        "BsmtFinType2", "FireplaceQu","GarageType","GarageFinish",
                        "GarageQual","GarageCond","PoolQC","Fence","MiscFeature")

empty_means_NA <- c("MasVnrType","Electrical")

# %%
replace_empty_with_without <- function(feature) {
    levels(feature) <- c(levels(feature), "without")
    empty_string_mask <- feature == ''
    feature[empty_string_mask] <- "without"
    return(feature)
}

replace_empty_with_NA <- function(feature) {
    levels(feature) <- c(levels(feature), NA)
    empty_string_mask <- feature == ''
    feature[empty_string_mask] <- NA
    return(feature)
}

# %%
for (feature in empty_means_without) {
    housing_df[,feature] <- replace_empty_with_without(feature)
}

for (feature in empty_means_NA) {
    housing_df[,feature] <- replace_empty_with_NA(feature)
}

# %%
housing_df
# Out:
#      X    MSSubClass MSZoning LotFrontage LotArea LotShape LandContour
# 1     1   60         RL        65.00000    8450   Reg      Lvl
# 2     2   20         RL        80.00000    9600   Reg      Lvl
# 3     3   60         RL        68.00000   11250   IR1      Lvl
# 4     4   70         RL        60.00000    9550   IR1      Lvl
# 5     5   60         RL        84.00000   14260   IR1      Lvl
# 6     6   50         RL        85.00000   14115   IR1      Lvl
# 7     7   20         RL        75.00000   10084   Reg      Lvl
# 8     8   60         RL        70.04996   10382   IR1      Lvl
# 9     9   50         RM        51.00000    6120   Reg      Lvl
# 10   10   190        RL        50.00000    7420   Reg      Lvl
# 11   11   20         RL        70.00000   11200   Reg      Lvl
# 12   12   60         RL        85.00000   11924   IR1      Lvl
# 13   13   20         RL        70.04996   12968   IR2      Lvl
# 14   14   20         RL        91.00000   10652   IR1      Lvl
# 15   15   20         RL        70.04996   10920   IR1      Lvl
# 16   16   45         RM        51.00000    6120   Reg      Lvl
# 17   17   20         RL        70.04996   11241   IR1      Lvl
# 18   18   90         RL        72.00000   10791   Reg      Lvl
# 19   19   20         RL        66.00000   13695   Reg      Lvl
# 20   20   20         RL        70.00000    7560   Reg      Lvl
# 21   21   60         RL       101.00000   14215   IR1      Lvl
# 22   22   45         RM        57.00000    7449   Reg      Bnk
# 23   23   20         RL        75.00000    9742   Reg      Lvl
# 24   24   120        RM        44.00000    4224   Reg      Lvl
# 25   25   20         RL        70.04996    8246   IR1      Lvl
# 26   26   20         RL       110.00000   14230   Reg      Lvl
# 27   27   20         RL        60.00000    7200   Reg      Lvl
# 28   28   20         RL        98.00000   11478   Reg      Lvl
# 29   29   20         RL        47.00000   16321   IR1      Lvl
# 30   30   30         RM        60.00000    6324   IR1      Lvl
# ⋮    ⋮    ⋮          ⋮        ⋮           ⋮       ⋮        ⋮
# 1431 1431 60         RL       60.00000    21930   IR3      Lvl
# 1432 1432 120        RL       70.04996     4928   IR1      Lvl
# 1433 1433 30         RL       60.00000    10800   Reg      Lvl
# 1434 1434 60         RL       93.00000    10261   IR1      Lvl
# 1435 1435 20         RL       80.00000    17400   Reg      Low
# 1436 1436 20         RL       80.00000     8400   Reg      Lvl
# 1437 1437 20         RL       60.00000     9000   Reg      Lvl
# 1438 1438 20         RL       96.00000    12444   Reg      Lvl
# 1439 1439 20         RM       90.00000     7407   Reg      Lvl
# 1440 1440 60         RL       80.00000    11584   Reg      Lvl
# 1441 1441 70         RL       79.00000    11526   IR1      Bnk
# 1442 1442 120        RM       70.04996     4426   Reg      Lvl
# 1443 1443 60         FV       85.00000    11003   Reg      Lvl
# 1444 1444 30         RL       70.04996     8854   Reg      Lvl
# 1445 1445 20         RL       63.00000     8500   Reg      Lvl
# 1446 1446 85         RL       70.00000     8400   Reg      Lvl
# 1447 1447 20         RL       70.04996    26142   IR1      Lvl
# 1448 1448 60         RL       80.00000    10000   Reg      Lvl
# 1449 1449 50         RL       70.00000    11767   Reg      Lvl
# 1450 1450 180        RM       21.00000     1533   Reg      Lvl
# 1451 1451 90         RL       60.00000     9000   Reg      Lvl
# 1452 1452 20         RL       78.00000     9262   Reg      Lvl
# 1453 1453 180        RM       35.00000     3675   Reg      Lvl
# 1454 1454 20         RL       90.00000    17217   Reg      Lvl
# 1455 1455 20         FV       62.00000     7500   Reg      Lvl
# 1456 1456 60         RL       62.00000     7917   Reg      Lvl
# 1457 1457 20         RL       85.00000    13175   Reg      Lvl
# 1458 1458 70         RL       66.00000     9042   Reg      Lvl
# 1459 1459 20         RL       68.00000     9717   Reg      Lvl
# 1460 1460 20         RL       75.00000     9937   Reg      Lvl
#      Utilities LotConfig LandSlope ⋯ PoolArea PoolQC Fence MiscFeature MiscVal
# 1    AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 2    AllPub    FR2       Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 3    AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 4    AllPub    Corner    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 5    AllPub    FR2       Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 6    AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature 700
# 7    AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 8    AllPub    Corner    Gtl       ⋯ 0        PoolQC Fence MiscFeature 350
# 9    AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 10   AllPub    Corner    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 11   AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 12   AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 13   AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 14   AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 15   AllPub    Corner    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 16   AllPub    Corner    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 17   AllPub    CulDSac   Gtl       ⋯ 0        PoolQC Fence MiscFeature 700
# 18   AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature 500
# 19   AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 20   AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 21   AllPub    Corner    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 22   AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 23   AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 24   AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 25   AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 26   AllPub    Corner    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 27   AllPub    Corner    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 28   AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 29   AllPub    CulDSac   Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# 30   AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature   0
# ⋮    ⋮         ⋮         ⋮         ⋱ ⋮        ⋮      ⋮     ⋮           ⋮
# 1431 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1432 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1433 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1434 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1435 AllPub    Inside    Mod       ⋯ 0        PoolQC Fence MiscFeature    0
# 1436 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1437 AllPub    FR2       Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1438 AllPub    FR2       Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1439 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1440 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1441 AllPub    Inside    Mod       ⋯ 0        PoolQC Fence MiscFeature    0
# 1442 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1443 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1444 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1445 AllPub    FR2       Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1446 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1447 AllPub    CulDSac   Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1448 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1449 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1450 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1451 AllPub    FR2       Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1452 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1453 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1454 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1455 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1456 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1457 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1458 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature 2500
# 1459 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
# 1460 AllPub    Inside    Gtl       ⋯ 0        PoolQC Fence MiscFeature    0
#      MoSold YrSold SaleType SaleCondition SalePrice
# 1    2      2008   WD       Normal        208500
# 2    5      2007   WD       Normal        181500
# 3    9      2008   WD       Normal        223500
# 4    2      2006   WD       Abnorml       140000
# 5    12     2008   WD       Normal        250000
# 6    10     2009   WD       Normal        143000
# 7    8      2007   WD       Normal        307000
# 8    11     2009   WD       Normal        200000
# 9    4      2008   WD       Abnorml       129900
# 10   1      2008   WD       Normal        118000
# 11   2      2008   WD       Normal        129500
# 12   7      2006   New      Partial       345000
# 13   9      2008   WD       Normal        144000
# 14   8      2007   New      Partial       279500
# 15   5      2008   WD       Normal        157000
# 16   7      2007   WD       Normal        132000
# 17   3      2010   WD       Normal        149000
# 18   10     2006   WD       Normal         90000
# 19   6      2008   WD       Normal        159000
# 20   5      2009   COD      Abnorml       139000
# 21   11     2006   New      Partial       325300
# 22   6      2007   WD       Normal        139400
# 23   9      2008   WD       Normal        230000
# 24   6      2007   WD       Normal        129900
# 25   5      2010   WD       Normal        154000
# 26   7      2009   WD       Normal        256300
# 27   5      2010   WD       Normal        134800
# 28   5      2010   WD       Normal        306000
# 29   12     2006   WD       Normal        207500
# 30   5      2008   WD       Normal         68500
# ⋮    ⋮      ⋮      ⋮        ⋮             ⋮
# 1431 7      2006   WD       Normal        192140
# 1432 10     2009   WD       Normal        143750
# 1433 8      2007   WD       Normal         64500
# 1434 5      2008   WD       Normal        186500
# 1435 5      2006   WD       Normal        160000
# 1436 7      2008   COD      Abnorml       174000
# 1437 5      2007   WD       Normal        120500
# 1438 11     2008   New      Partial       394617
# 1439 4      2010   WD       Normal        149700
# 1440 11     2007   WD       Normal        197000
# 1441 9      2008   WD       Normal        191000
# 1442 5      2008   WD       Normal        149300
# 1443 4      2009   WD       Normal        310000
# 1444 5      2009   WD       Normal        121000
# 1445 11     2007   WD       Normal        179600
# 1446 5      2007   WD       Normal        129000
# 1447 4      2010   WD       Normal        157900
# 1448 12     2007   WD       Normal        240000
# 1449 5      2007   WD       Normal        112000
# 1450 8      2006   WD       Abnorml        92000
# 1451 9      2009   WD       Normal        136000
# 1452 5      2009   New      Partial       287090
# 1453 5      2006   WD       Normal        145000
# 1454 7      2006   WD       Abnorml        84500
# 1455 10     2009   WD       Normal        185000
# 1456 8      2007   WD       Normal        175000
# 1457 2      2010   WD       Normal        210000
# 1458 5      2010   WD       Normal        266500
# 1459 4      2010   WD       Normal        142125
# 1460 6      2008   WD       Normal        147500

# %%
housing_df <- na.omit(housing_df)

# %%
count_empty_total()
